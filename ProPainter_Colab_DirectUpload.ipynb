# %% [markdown]
# # ProPainter - Direct Upload to /content
#
# **Instructions:**
# 1. On your local PC, create a `.zip` file of your `WatermarkRM` folder. *(Tip: To make the upload faster, do NOT include the `venv` folder in the zip file.)*
# 2. Run the first cell below to upload the `.zip` file directly into Colab's `/content` directory.
# 3. Colab will automatically unzip it and prepare the environment.
# 4. Run the final cell to start the web app.

# %%
# 1. Upload your project zip file to Colab
import os
from google.colab import files

print("Please select the WatermarkRM.zip file from your local PC:")
uploaded = files.upload()
zip_filename = list(uploaded.keys())[0]

# 2. Unzip the project into /content/WatermarkRM
# !unzip -q -o {zip_filename} -d /content/WatermarkRM
print(f"Successfully extracted {zip_filename} to /content/WatermarkRM")

# %%
# 3. Navigate to the extracted folder and install dependencies
# %cd /content/WatermarkRM

# !pip install -r requirements.txt
# !pip install gradio ultralytics

# %%
# 4. Run the app!
# Note: Colab runs Linux, so we use 'python' instead of the Windows 'py' command.
# !python app.py --cloudflare
